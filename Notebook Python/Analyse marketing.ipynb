# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv("marketing.csv")
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced   84835.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2     10476        1958  Graduation        Married   67267.0        0
# 3      1386        1967  Graduation       Together   32474.0        1
# 4      5371        1989  Graduation         Single   21474.0        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced   66476.0        0
# 2236   5263        1977    2n Cycle        Married   31056.0        1
# 2237     22        1976  Graduation       Divorced   46310.0        1
# 2238    528        1978  Graduation        Married   65819.0        0
# 2239   4070        1969         PhD        Married   94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.shape ##demension###
# Out:
# (2240, 28)

# %%
df.info() #la structure (types, colonnes, données manquantes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntBakedProds        2240 non-null   int64
# ...

# %%
df.describe() #les statestiques
# Out:
#                  ID   Year_Birth        Income       Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %% [markdown]
# NOTRE BUYER PERSONA
#
# 1. Profil Démographique (Le "Qui")
# Âge : Environ 55-58 ans (Génération X). Né autour de 1970.
#
# Situation Familiale : Souvent en couple ("Married" ou "Together" sont les modalités majoritaires).
#
# Foyer : Pas d'enfants en bas âge (Médiane de Kidhome à 0). S'il y a des enfants, ce sont plutôt des adolescents (Teenhome).
#
# Éducation : Hautement diplômé (Majorité de "Graduation", "PhD" ou "Master").
#
# Revenu : Confortable, avec une moyenne de 52 250 $ (Classe moyenne supérieure).
#
# 2. Habitudes de Consommation (Le "Quoi")
# Sa Passion : Le Vin. C'est de loin sa plus grosse dépense (303 $ en moyenne).
#
# Son Régime : Amateur de protéines. La Viande est son deuxième poste de dépense (166 $).
#
# Panier Moyen : Élevé. Il ne vient pas pour des petites courses, mais pour des produits plaisirs et qualitatifs.
#
# Santé / Bio : Faible intérêt pour les produits sucrés ou les fruits par rapport au reste.
#
# 3. Comportement d'Achat (Le "Comment")
# Canal Préféré : Le Magasin physique (5.8 achats en moyenne). Il aime probablement voir les produits ou bénéficier de conseils.
#
# Digitalisation : Il est "Web-hybride". Il visite le site 5 fois par mois, mais n'y achète que 4 fois. Il utilise peut-être le site pour comparer avant d'acheter.
#
# Sensibilité aux Promotions : Modérée. Il fait environ 2 à 3 achats avec des "Deals", mais il n'est pas un chasseur de promotions compulsif.
#
# 4. Relation à la Marque (L'Engagement)
# Fidélité : Client de longue date (inscrit souvent depuis 2012-2014).
#
# Réactivité Marketing : Difficile à convaincre. Il a ignoré les premières campagnes, mais commence à réagir positivement à la dernière (taux de réponse de 15%).
#
# Satisfaction : Très satisfait. Il ne se plaint quasiment jamais (moins de 1% de plaintes)

# %%
df.duplicated().sum() # 0 duplicated
# Out:
# np.int64(0)

# %% [markdown]
# Analyse de la Performance par Catégorie

# %%
mnt_cols = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntBakedProds']

# Calcul de la moyenne
product_performance = df[mnt_cols].mean().sort_values(ascending=True) # Calcul du montant moyen dépensé par produit et tri par performance croissante

# Création du graphique
product_performance.plot(kind='barh', color=colors)

plt.title('Performance Moyenne par Catégorie de Produit')
plt.xlabel('Dépense Moyenne ($)')
plt.ylabel('Produits')
# Out:
# Text(0, 0.5, 'Produits')

# %%
# Liste des colonnes "Montants"
mnt_cols = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntBakedProds']

# Création du Boxplot horizontal
sns.boxplot(data=df[mnt_cols], orient="h")

plt.title('Comparaison de la Performance par Catégorie de Produit')
plt.xlabel('Montant des Ventes ($)')
plt.ylabel('Catégories de Produits')
# Out:
# Text(0, 0.5, 'Catégories de Produits')

# %%
# On utilise "MntWines" car c'est le produit, pas "Income"
sns.histplot(data=df, x="MntWines")

plt.title('Analyse Produit : Distribution des Dépenses en Vin')
plt.xlabel('Montant dépensé en Vin ($)')
plt.ylabel('Nombre de Clients')
# Out:
# Text(0, 0.5, 'Nombre de Clients')

# %% [markdown]
# Remarques : Le catalogue est porté par un duo 'Vin & Viande'. Alors que la majorité des clients ont une consommation prudente, la rentabilité de l'entreprise repose sur une minorité de clients fidèles et aisés (les outliers) qui consomment des produits de luxe sur de larges plages de prix

# %% [markdown]
# Comparaison des Canaux d'Achat

# %%
# Colonnes des canaux
channels = ['NumStorePurchases', 'NumWebPurchases', 'NumCatalogPurchases']
channel_data = df[channels].mean().sort_values(ascending=False)

sns.barplot(x=channel_data.index, y=channel_data.values)

plt.title('Préférence des Canaux d\'Achat')
plt.ylabel('Nombre moyen d\'achats')
plt.xlabel('Canaux de vente')
# Out:
# Text(0.5, 0, 'Canaux de vente')

# %% [markdown]
# Analyse de la Performance par demographique

# %%
# Calcul de l'âge (en prenant 2026 comme année de référence)
df['Age'] = 2026 - df['Year_Birth']

sns.histplot(df['Age'] )
plt.title('Distribution de l\'Âge des Clients')
# Out:
# Text(0.5, 1.0, "Distribution de l'Âge des Clients")

# %% [markdown]
# "Notre client idéal est un adulte de 55 ans, diplômé de l'enseignement supérieur, disposant d'un revenu confortable. Il vit dans un foyer sans jeunes enfants, ce qui lui permet de privilégier des achats de qualité en magasin physique."
